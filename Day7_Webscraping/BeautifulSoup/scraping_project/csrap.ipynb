# %%
pip install requests beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install grequests
# Out:
# ...
#      ---------------------------------------- 1.5/1.5 MB 352.2 kB/s eta 0:00:00
# ...
#      -------------------------------------- 204.1/204.1 kB 1.2 MB/s eta 0:00:00
# ...
#      ------------------------------------ 192.2/192.2 kB 431.1 kB/s eta 0:00:00
# ...
#      ------------------------------------ 179.1/179.1 kB 718.4 kB/s eta 0:00:00
# ...
#      ------------------------------------ 118.7/118.7 kB 407.7 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

URL = "https://www.laufen.co.at/produkte/mobelwaschtisch-ablage-links-verdecktem-uberlauf-inkl-ablaufventil-ventilabdeckung-keramik-H814974...1041?sku=H8149744001041"
headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246"}
# Here the user agent is for Edge browser on windows 10. You can find your browser user agent from the above given link.
r = requests.get(url=URL, headers=headers)
print(r.content)
# Out:
# b'\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\t\n\t\t\n\t\t\t<!DOCTYPE html>\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n<html class="ltr" dir="ltr" lang="de">\r\n\r\n<head>\r\n\r\n\r\n\t<title>M\xc3\xb6belwaschtisch, Ablage links, mit verdecktem \xc3\x9cberlauf, inkl. Ablaufventil mit Ventilabdeckung Keramik (H8149744001041) | Laufen Bathrooms</title>\r\n\r\n\t<!-- Default meta tags -->\r\n\r\n\t<meta content="initial-scale=1.0, width=device-width" name="viewport" />\r\n\t<meta content="text/html; charset=UTF-8" http-equiv="content-type" />\r\n\t\r\n\t\r\n\t<!-- Description meta -->\r\n\t\r\n\t<meta name="description" lang="de-DE" content="M\xc3\xb6belwaschtisch, Ablage links, mit verdecktem \xc3\x9cberlauf, inkl. Ablaufventil mit Ventilabdeckung Keramik, 1200 x 
# ...

# %%
soup = BeautifulSoup(r.content, 'html5lib') 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="ltr" dir="ltr" lang="de">
#  <head>
#   <title>
#    Möbelwaschtisch, Ablage links, mit verdecktem Überlauf, inkl. Ablaufventil mit Ventilabdeckung Keramik (H8149744001041) | Laufen Bathrooms
#   </title>
#   <!-- Default meta tags -->
#   <meta content="initial-scale=1.0, width=device-width" name="viewport"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <!-- Description meta -->
#   <meta content="Möbelwaschtisch, Ablage links, mit verdecktem Überlauf, inkl. Ablaufventil mit Ventilabdeckung Keramik, 1200 x 500 x 140 mm, 47.24 x 19.69 x 6.5 in, ILBAGNOALESSI, Waschtische wandhängend, LAUFEN. H814974...1041" lang="de-DE" name="description"/>
#   <!-- Canonical, next, prev links -->
#   <link href="https://www.laufen.co.at/produkte/mobelwaschtisch-ablage-links-verdecktem-uberlauf-inkl-ablaufventil-ventilabdeckung-keramik-H814974...1041" rel="canonical"/>
#   <!-- OpenGraph metas -->
# ...

# %%
product_containers = soup.find_all('div', class_='product-detail-v2-blue-background')

# %%
name = product_containers.find_all('div', class_='coleccion-name').text.strip()
name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\BeautifulSoup\scraping_project\csrap.ipynb Cell 6 in 1
# ----> <a href='vscode-notebook-cell:/d%3A/BeautifulSoup/scraping_project/csrap.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> name = product_containers.find_all('div', class_='coleccion-name').text.strip()
#       <a href='vscode-notebook-cell:/d%3A/BeautifulSoup/scraping_project/csrap.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> name
#
# File c:\Users\A\AppData\Local\Programs\Python\Python310\lib\site-packages\bs4\element.py:2290, in ResultSet.__getattr__(self, key)
#    2288 def __getattr__(self, key):
#    2289     """Raise a helpful exception to explain a common code fix."""
# -> 2290     raise AttributeError(
# ...

# %%
#for container in product_containers:
        # Extract the relevant information for each product
category1 = soup.find('a', class_='bread-link-1').text.strip()
category2 = soup.find('a', class_='bread-link-2').text.strip()
series = soup.find('h1', class_='product-title').text.strip()
name = container.find('a', class_='product-name').text.strip()
article_number = container.find('span', class_='product-ean').text.strip()
dimensions = container.find('div', class_='product-dimensions').text.strip().split('x')
length = dimensions[0].strip()
width = dimensions[1].strip()
height = dimensions[2].strip()
color = container.find('div', class_='product-color').text.strip()
product_type = container.find('div', class_='product-type').text.strip()
short_description = container.find('div', class_='product-short-desc').text.strip()
material = container.find('div', class_='product-material').text.strip()
datasheet = container.find('a', class_='product-datasheet')['href']
data_3d = container.find('a', class_='product-3d-data')['href']
long_description = container.find('div', class_='product-long-desc').text.strip()
main_image = container.find('img')['src']
gallery_images = [img['src'] for img in container.find_all('img', class_='product-gallery-image')]
product_url = container.find('a', class_='product-name')['href']
# Out:
# [<div class="product-detail-v2-blue-background">
#
#  <div class="container">
#
#
#  	<div class="row">
#
#  		<div class="col-lg-6 col-12">
#  			<div class="product-card">
#  				<div class="wrapper-producto wrapper-producto-overflow has-modal">
#  					<div class="tags">
#
#  					</div>
#  					<div class="image-overflow">
#  						<div class="slider slider-single">
#
#  							<div>
#  								<a data-target="#detail-product-img" data-toggle="modal" role="button">
#
#  									<img alt="Waschtische wandhängend Weiẞ LCC (LAUFEN Clean Coat) ILBAGNOALESSI ONE H8149744001041 Laufen" data-finish="n-finished-H8149744001041" data-option="" src="/LaufenResourceServlet/resources/getTransformation?idObject=2f0bd5da2e36374f3c9ed37f14ecec0b&amp;trName=TF_Mob_prod_xxl_v2"/>
#
#  									</a>
#  								</div>
#
#  							<div>
#  								<a data-target="#detail-product-img" data-toggle="modal" role="button">
#
# ...
